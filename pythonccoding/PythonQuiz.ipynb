# %% [markdown]
# # Python Quiz from
#     @Pythonclcoding channel of
#     https://www.youtube.com/shorts/KnXyEJIt-eU

# %%
my_list = [1,2,3]
my_tuple =(4,5,6)
result = my_list + list(my_tuple)

print(result)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
my_string ="hello, world!"
print(my_string[7:])
# Out:
# world!

# %%
x = 10
def foo():
    global x
    x = 20

foo()
print(x)
# Out:
# 20

# %%
x = [1,2,3]
y = [3,4,5]
z = zip(x,y)
print(list(z))
print(x+y)
# Out:
# [(1, 3), (2, 4), (3, 5)]
# [1, 2, 3, 3, 4, 5]

# %%
my_dict = {"a":100,"b":20,"c":140}
for a,b in my_dict.items():
    print(a,",",b)
# Out:
# a , 100
# b , 20
# c , 140

# %%
def my_func(x):
    if x == 0:
        return 0
    else:
        return x + my_func(x-1)

print(my_func(5))
# Out:
# 15

# %%
my_dict = {"a":10,"b":25,"c":30}
k = my_dict.keys()
print(my_dict.keys())
print(k)
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_keys(['a', 'b', 'c'])

# %%
my_list = [1,2,3,4,5]
my_list = my_list.pop() # It will pop out/remove out the last element
print(my_list)
# Out:
# 5

# %%
def my_function():
    x = 10
    def inner_function():
        nonlocal x
        x +=5
    inner_function()
    print(x)

my_function()
# Out:
# 15

# %%
def my_func():
    try:
        print("hello")
        return
    finally:
        print("world")
my_func()
# Out:
# hello
# world

# %%
lst = [1,2,3,4,5]
new_lst = [i * i for i in lst if i % 2 == 0]
print(new_lst)
# Out:
# [4, 16]

# %%
lst = [1,2,3,4,5]

for i in lst:
    if i == 3:
        break
    print(i)
else:
    print("completed successfully")
# Out:
# 1
# 2

# %%
x = [1,2,3]
y = x
x.append(4)
print(y)
# Out:
# [1, 2, 3, 4]

# %%
for i in range(3): # 0,1,2
    for j in range(3): # 0,1,2
        print(i*j)
# Out:
# 0
# 0
# 0
# 0
# 1
# 2
# 0
# 2
# 4
